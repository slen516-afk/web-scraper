# %% [markdown]
# ### Requests 夾帶 cookie

# %%
import requests
from bs4 import BeautifulSoup as bs

 # PTT Gossiiping (八卦版) 
url = "https://www.ptt.cc/bbs/Gossiping/index.html"

# 首頁網址
prefix = 'https://www.ptt.cc'

# 設定 cookie
# my_cookies = {
#     "over18": "1"
# }

# 用 requests 的 get 方法把網頁抓下來
res = requests.get(url) 

# 指定 lxml 作為解析器
soup = bs(res.text, "lxml")

# 顯示連結列表
for a in soup.select('div.r-ent > div.title > a'):
    print(a.get_text())
    print(prefix + a['href'])
# Out:
# Re: [問卦] 我朋友越想越不對勁?!
# https://www.ptt.cc/bbs/Gossiping/M.1763199107.A.757.html
# [新聞] 櫻花妹廁所前「肉體交疊」非裔男畫面曝
# https://www.ptt.cc/bbs/Gossiping/M.1763199133.A.2C6.html
# [新聞] 嘉義縣首件普發萬元補助詐騙案 嫌犯收押
# https://www.ptt.cc/bbs/Gossiping/M.1763199136.A.398.html
# [問卦] 織田信長時期的日本 打得贏熊嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1763199219.A.22D.html
# Re: [問卦] 中國人：可憐, 台灣用落後Line軟件
# https://www.ptt.cc/bbs/Gossiping/M.1763199227.A.CE2.html
# [問卦] 16個人去夜市點5份牛排會怎樣？
# https://www.ptt.cc/bbs/Gossiping/M.1763199251.A.079.html
# [問卦] 日本特攝片到底了嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1763199256.A.BF8.html
# Re: [新聞] 光電加嚴環評！6環團聯合聲明反對 名醫
# https://www.ptt.cc/bbs/Gossiping/M.1763199363.A.39C.html
# [公告] 八卦板板規(2025.01.21)
# https://www.ptt.cc/bbs/Gossiping/M.1737398137.A.644.html
# Re: [問卦] 請勿前往光復區，鏟子超人任務艱鉅，病例增。
# https://www.ptt.cc/bbs/Gossiping/M.1759065775.A.9B4.html
# [公告] 【八卦美學獎】梗圖吐槽，共鳴豹紋笑翻！
# https://www.ptt.cc/bbs/Gossiping/M.1761980569.A.84C.html
# [公告] 11/14 八卦踢報十大頭條 11月協尋 置底閒聊
# https://www.ptt.cc/bbs/Gossiping/M.1763077421.A.B5B.html
