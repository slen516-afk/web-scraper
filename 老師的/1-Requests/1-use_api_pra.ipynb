# %%
# %pip install requests

# %%
# 引入 requests 模組
import requests

# 測試用 API 網址
url = 'https://httpbin.org/'

# 發送 GET 請求並取得回應
response = requests.get(url)

if response.status_code != 200:
    print("回傳異常")

print(response)
# 回應的狀態碼
print(response.status_code)

# 回應的原始內容（位元組）
print(response.content)

# 回應的文字內容
print(response.text)
# print(response.headers)
# Out:
# <Response [200]>
# 200
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta charset="UTF-8">\n    <title>httpbin.org</title>\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700"\n        rel="stylesheet">\n    <link rel="stylesheet" type="text/css" href="/flasgger_static/swagger-ui.css">\n    <link rel="icon" type="image/png" href="/static/favicon.ico" sizes="64x64 32x32 16x16" />\n    <style>\n        html {\n            box-sizing: border-box;\n            overflow: -moz-scrollbars-vertical;\n            overflow-y: scroll;\n        }\n\n        *,\n        *:before,\n        *:after {\n            box-sizing: inherit;\n        }\n\n        body {\n            margin: 0;\n            background: #fafafa;\n        }\n    </style>\n</head>\n\n<body>\n    <a href="https://github.com/requests/httpbin" class="github-corner" aria-label="View source on Github">\n        <svg width="80" height="80" viewBox="0 0 250 250" style="fill:#151513; color:#fff; position: absolute; top: 0; border: 0; right: 0;"\n            aria-hidden="true">\n            <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 Z"></path>\n            <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 C122.0,82.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 C127.3,80.9 125.5,87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"\n                fill="currentColor" style="transform-origin: 130px 106px;" class="octo-arm"></path>\n            <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,115.4 L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 143.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 171.4,40.1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 190.9,65.4 C194.5,69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 216.3,84.9 C212.7,93.1 206.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 198.3,112.5 C181.9,128.9 168.3,122.5 157.7,114.1 C157.9,116.9 156.7,120.9 152.7,124.9 L141.0,136.5 C139.8,137.7 141.6,141.9 141.8,141.8 Z"\n                fill="currentColor" class="octo-body"></path>\n        </svg>\n    </a>\n    <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="position:absolute;width:0;height:0">\n        <defs>\n            <symbol viewBox="0 0 20 20" id="unlocked">\n                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8z"></path>\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="locked">\n                <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8zM12 8H8V5.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="close">\n                <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L10 11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 0-1.697l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 1.228-.469 1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 .469.469.469 1.229 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 1.698z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="large-arrow">\n                <path d="M13.25 10L6.109 2.58c-.268-.27-.268-.707 0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l-7.83 7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10z"\n                />\n            </symbol>\n\n            <symbol viewBox="0 0 20 20" id="large-arrow-down">\n            ...
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <title>httpbin.org</title>
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,700|Source+Code+Pro:300,600|Titillium+Web:400,600,700"
#         rel="stylesheet">
#     <link rel="stylesheet" type="text/css" href="/flasgger_static/swagger-ui.css">
#     <link rel="icon" type="image/png" href="/static/favicon.ico" sizes="64x64 32x32 16x16" />
#     <style>
#         html {
#             box-sizing: border-box;
#             overflow: -moz-scrollbars-vertical;
#             overflow-y: scroll;
#         }
#
#         *,
#         *:before,
#         *:after {
#             box-sizing: inherit;
#         }
#
#         body {
#             margin: 0;
#             background: #fafafa;
#         }
#     </style>
# </head>
#
# <body>
#     <a href="https://github.com/requests/httpbin" class="github-corner" aria-label="View source on Github">
#         <svg width="80" height="80" viewBox="0 0 250 250" style="fill:#151513; color:#fff; position: absolute; top: 0; border: 0; right: 0;"
#             aria-hidden="true">
#             <path d="M0,0 L115,115 L130,115 L142,142 L250,250 L250,0 Z"></path>
#             <path d="M128.3,109.0 C113.8,99.7 119.0,89.6 119.0,89.6 C122.0,82.7 120.5,78.6 120.5,78.6 C119.2,72.0 123.4,76.3 123.4,76.3 C127.3,80.9 125.5,87.3 125.5,87.3 C122.9,97.6 130.6,101.9 134.4,103.2"
#                 fill="currentColor" style="transform-origin: 130px 106px;" class="octo-arm"></path>
#             <path d="M115.0,115.0 C114.9,115.1 118.7,116.5 119.8,115.4 L133.7,101.6 C136.9,99.2 139.9,98.4 142.2,98.6 C133.8,88.0 127.5,74.4 143.8,58.0 C148.5,53.4 154.0,51.2 159.7,51.0 C160.3,49.4 163.2,43.6 171.4,40.1 C171.4,40.1 176.1,42.5 178.8,56.2 C183.1,58.6 187.2,61.8 190.9,65.4 C194.5,69.0 197.7,73.2 200.1,77.6 C213.8,80.2 216.3,84.9 216.3,84.9 C212.7,93.1 206.9,96.0 205.4,96.6 C205.1,102.4 203.0,107.8 198.3,112.5 C181.9,128.9 168.3,122.5 157.7,114.1 C157.9,116.9 156.7,120.9 152.7,124.9 L141.0,136.5 C139.8,137.7 141.6,141.9 141.8,141.8 Z"
#                 fill="currentColor" class="octo-body"></path>
#         </svg>
#     </a>
#     <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="position:absolute;width:0;height:0">
#         <defs>
#             <symbol viewBox="0 0 20 20" id="unlocked">
#                 <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V6h2v-.801C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8z"></path>
#             </symbol>
#
#             <symbol viewBox="0 0 20 20" id="locked">
#                 <path d="M15.8 8H14V5.6C14 2.703 12.665 1 10 1 7.334 1 6 2.703 6 5.6V8H4c-.553 0-1 .646-1 1.199V17c0 .549.428 1.139.951 1.307l1.197.387C5.672 18.861 6.55 19 7.1 19h5.8c.549 0 1.428-.139 1.951-.307l1.196-.387c.524-.167.953-.757.953-1.306V9.199C17 8.646 16.352 8 15.8 8zM12 8H8V5.199C8 3.754 8.797 3 10 3c1.203 0 2 .754 2 2.199V8z"
#                 />
#             </symbol>
#
#             <symbol viewBox="0 0 20 20" id="close">
#                 <path d="M14.348 14.849c-.469.469-1.229.469-1.697 0L10 11.819l-2.651 3.029c-.469.469-1.229.469-1.697 0-.469-.469-.469-1.229 0-1.697l2.758-3.15-2.759-3.152c-.469-.469-.469-1.228 0-1.697.469-.469 1.228-.469 1.697 0L10 8.183l2.651-3.031c.469-.469 1.228-.469 1.697 0 .469.469.469 1.229 0 1.697l-2.758 3.152 2.758 3.15c.469.469.469 1.229 0 1.698z"
#                 />
#             </symbol>
#
#             <symbol viewBox="0 0 20 20" id="large-arrow">
#                 <path d="M13.25 10L6.109 2.58c-.268-.27-.268-.707 0-.979.268-.27.701-.27.969 0l7.83 7.908c.268.271.268.709 0 .979l-7.83 7.908c-.268.271-.701.27-.969 0-.268-.269-.268-.707 0-.979L13.25 10z"
#                 />
#             </symbol>
#
#             <symbol viewBox="0 0 20 20" id="large-arrow-down">
#                 <path d="M17.418 6.109c.272-.268.709-.268.979 0s.271.701 0 .969l-7.908 7.83c-.27.268-.707.268-.979 0l-7.908-7.83c-.27-.268-.27-.701 0-.969.271-.268.709-.268.979 0L10 13.25l7.418-7.141z"
#                 />
#             </symbol>
#
#
#             <symbol viewBox="0 0 24 24" id="jump-to">
#                 <path d="M19 7v4H5.83l3.58-3.59L8 6l-6 6 6 6 1.41-1.41L5.83 13H21V7z" />
#             </symbol>
#
#             <symbol viewBox="0 0 24 24" id="expand">
#                 <path d="M10 18h4v-2h-4v2zM3 6v2h18V6H3zm3 7h12v-2H6v2z" />
#             </symbol>
#
#         </defs>
#     </svg>
#
#
#     <div id="swagger-ui">
#         <div data-reactroot="" class="swagger-ui">
#             <div>
#                 <div class="information-container wrapper">
#                     <section class="block col-12">
#                         <div class="info">
#                             <hgroup class="main">
#                                 <h2 class="title">httpbin.org
#                                     <small>
#                                         <pre class="version">0.9.2</pre>
#                                     </small>
#                                 </h2>
#                                 <pre class="base-url">[ Base URL: httpbin.org/ ]</pre>
#                             </hgroup>
#                             <div class="description">
#                                 <div class="markdown">
#                                     <p>A simple HTTP Request &amp; Response Service.
#                                         <br>
#                                         <br>
#                                         <b>Run locally: </b>
#                                         <code>$ docker run -p 80:80 kennethreitz/httpbin</code>
#                                     </p>
#                                 </div>
#                             </div>
#                             <div>
#                                 <div>
#                                     <a href="https://kennethreitz.org" target="_blank">the developer - Website</a>
#                                 </div>
#                                 <a href="mailto:me@kennethreitz.org">Send email to the developer</a>
#                             </div>
#                         </div>
#                         <!-- ADDS THE LOADER SPINNER -->
#                         <div class="loading-container">
#                             <div class="loading"></div>
#                         </div>
#
#                     </section>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#
#     <div class='swagger-ui'>
#         <div class="wrapper">
#             <section class="clear">
#                 <span style="float: right;">
#                     [Powered by
#                     <a target="_blank" href="https://github.com/rochacbruno/flasgger">Flasgger</a>]
#                     <br>
#                 </span>
#             </section>
#         </div>
#     </div>
#
#
#
#     <script src="/flasgger_static/swagger-ui-bundle.js"> </script>
#     <script src="/flasgger_static/swagger-ui-standalone-preset.js"> </script>
#     <script src='/flasgger_static/lib/jquery.min.js' type='text/javascript'></script>
#     <script>
#
#         window.onload = function () {
#
#
#             fetch("/spec.json")
#                 .then(function (response) {
#                     response.json()
#                         .then(function (json) {
#                             var current_protocol = window.location.protocol.slice(0, -1);
#                             if (json.schemes[0] != current_protocol) {
#                                 // Switches scheme to the current in use
#                                 var other_protocol = json.schemes[0];
#                                 json.schemes[0] = current_protocol;
#                                 json.schemes[1] = other_protocol;
#
#                             }
#                             json.host = window.location.host;  // sets the current host
#
#                             const ui = SwaggerUIBundle({
#                                 spec: json,
#                                 validatorUrl: null,
#                                 dom_id: '#swagger-ui',
#                                 deepLinking: true,
#                                 jsonEditor: true,
#                                 docExpansion: "none",
#                                 apisSorter: "alpha",
#                                 //operationsSorter: "alpha",
#                                 presets: [
#                                     SwaggerUIBundle.presets.apis,
#                                     // yay ES6 modules ↘
#                                     Array.isArray(SwaggerUIStandalonePreset) ? SwaggerUIStandalonePreset : SwaggerUIStandalonePreset.default
#                                 ],
#                                 plugins: [
#                                     SwaggerUIBundle.plugins.DownloadUrl
#                                 ],
#
#             // layout: "StandaloneLayout"  // uncomment to enable the green top header
#         })
#
#         window.ui = ui
#
#         // uncomment to rename the top brand if layout is enabled
#         // $(".topbar-wrapper .link span").replaceWith("<span>httpbin</span>");
#         })
#     })
# }
#     </script>  <div class='swagger-ui'>
#     <div class="wrapper">
#         <section class="block col-12 block-desktop col-12-desktop">
#             <div>
#
#                 <h2>Other Utilities</h2>
#
#                 <ul>
#                     <li>
#                         <a href="/forms/post">HTML form</a> that posts to /post /forms/post</li>
#                 </ul>
#
#                 <br />
#                 <br />
#             </div>
#         </section>
#     </div>
# </div>
# </body>
#
# </html>

# %%
import json
# 使用 GET 搭配參數
# 'https://httpbin.org/get'
r = requests.get(url+'get', params={"city": "Taipei"})
# print(r.text)
# print(r.json())
# data = r.json()
# data["args"]

# 等同於使用下面的寫法
r = requests.get(url+'get'+'?city=Taipei')
# print(r.text)

data = json.loads(r.text)
print(type(data))


# print(data['args'])
# print(r.json())
# Out:
# <class 'dict'>

# %%
# 使用 POST 搭配 data (常用在表單提交)
r = requests.post(url+'post', data={"username": "Jarvis"})
print(r.json())
# Out:
# {'args': {}, 'data': '', 'files': {}, 'form': {'username': 'Jarvis'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, zstd', 'Content-Length': '15', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.5', 'X-Amzn-Trace-Id': 'Root=1-6917e8a8-4a08c49d7a78a3980e7bc071'}, 'json': None, 'origin': '1.160.4.145', 'url': 'https://httpbin.org/post'}

# %%
# 使用 POST 搭配 JSON (常用在 API 資料傳輸)
r = requests.post(url+'post', json={"username": "Jarvis"})
print(r.json())
# Out:
# {'args': {}, 'data': '{"username": "Jarvis"}', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, zstd', 'Content-Length': '22', 'Content-Type': 'application/json', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.5', 'X-Amzn-Trace-Id': 'Root=1-6917e8cb-51c7dc816d186f3b23f3f343'}, 'json': {'username': 'Jarvis'}, 'origin': '1.160.4.145', 'url': 'https://httpbin.org/post'}

# %%
import requests
"""
臺北捷運全系統旅運量統計資料
參考網址:
https://data.taipei/dataset/detail?id=660e3969-c011-481c-aa24-8a949ac2d62d
"""

base_url = "https://data.taipei/api/v1/dataset/84a29696-d12c-44b5-b1b9-cc91724fbe28?scope=resourceAquire"
params = ""
r = requests.get(base_url, verify=False)

print(r.json())
# Out:
# {'result': {'limit': 20, 'offset': 0, 'count': 31, 'sort': '', 'results': [{'_id': 1, '_importdate': {'date': '2025-10-16 09:09:26.528474', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '01', '星期': '五', '人次': '2308175'}, {'_id': 2, '_importdate': {'date': '2025-10-16 09:09:26.543562', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '02', '星期': '六', '人次': '1857014'}, {'_id': 3, '_importdate': {'date': '2025-10-16 09:09:26.545720', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '03', '星期': '日', '人次': '1579908'}, {'_id': 4, '_importdate': {'date': '2025-10-16 09:09:26.547334', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '04', '星期': '一', '人次': '2094468'}, {'_id': 5, '_importdate': {'date': '2025-10-16 09:09:26.548942', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '05', '星期': '二', '人次': '2148968'}, {'_id': 6, '_importdate': {'date': '2025-10-16 09:09:26.550795', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '06', '星期': '三', '人次': '2276954'}, {'_id': 7, '_importdate': {'date': '2025-10-16 09:09:26.552260', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '07', '星期': '四', '人次': '2286077'}, {'_id': 8, '_importdate': {'date': '2025-10-16 09:09:26.553531', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '08', '星期': '五', '人次': '2368659'}, {'_id': 9, '_importdate': {'date': '2025-10-16 09:09:26.554661', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '09', '星期': '六', '人次': '1945443'}, {'_id': 10, '_importdate': {'date': '2025-10-16 09:09:26.556180', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '10', '星期': '日', '人次': '1669343'}, {'_id': 11, '_importdate': {'date': '2025-10-16 09:09:26.557663', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '11', '星期': '一', '人次': '2180835'}, {'_id': 12, '_importdate': {'date': '2025-10-16 09:09:26.558885', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '12', '星期': '二', '人次': '2229896'}, {'_id': 13, '_importdate': {'date': '2025-10-16 09:09:26.560305', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '13', '星期': '三', '人次': '2060387'}, {'_id': 14, '_importdate': {'date': '2025-10-16 09:09:26.561591', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '14', '星期': '四', '人次': '2197377'}, {'_id': 15, '_importdate': {'date': '2025-10-16 09:09:26.563056', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '15', '星期': '五', '人次': '2385574'}, {'_id': 16, '_importdate': {'date': '2025-10-16 09:09:26.564301', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '16', '星期': '六', '人次': '2016115'}, {'_id': 17, '_importdate': {'date': '2025-10-16 09:09:26.565637', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '17', '星期': '日', '人次': '1711836'}, {'_id': 18, '_importdate': {'date': '2025-10-16 09:09:26.566934', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '18', '星期': '一', '人次': '2100698'}, {'_id': 19, '_importdate': {'date': '2025-10-16 09:09:26.568291', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '19', '星期': '二', '人次': '2199956'}, {'_id': 20, '_importdate': {'date': '2025-10-16 09:09:26.569765', 'timezone_type': 3, 'timezone': 'Asia/Taipei'}, '西元年': '2025', '月': '08', '日': '20', '星期': '三', '人次': '2265733'}]}}
# c:\Users\student\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.taipei'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import requests
"""
課堂練習 
參考網址: 'https://www.einvoice.nat.gov.tw/portal/ods/ODS318E/einvoice_open_data#/消費通路發票統計/ConsumpInvoiceStatic'
"""

base_url = "https://dataset.einvoice.nat.gov.tw/ods/portal"
# resource = "api/v1/ConsumpInvoiceStatic"
resource = "/api/v1/DonateScaleByBusiCd"

# r = requests.get(base_url+resource, params={"hsnNm": "臺北市"})
r = requests.get(base_url+resource)
# print(r.json())
data = r.json()

for i in data:
    # print(i)
    print(f"{i['busiNm']} - {i['invoiceCreateCnt']}")
# Out:
# 公共行政及國防；強制性社會安全 - 293
# 博弈業 - 11
# 石油及煤製品製造業 - 1152009
# 基本金屬製造業 - 18566
# 皮革、毛皮及其製品製造業 - 11211
# 電子零組件製造業 - 142571
# 批發業 - 5857607
# 郵政及快遞業 - 254557
# 電信業 - 28279066
# 資訊服務業 - 41622999
# 其他製造業 - 30244
# 電信業 - 22589114
# 教育業 - 235096
# 零售業 - 59516451
# 宗教、職業及類似組織 - 54371
# 砂、石採取及其他礦業 - 346
# 電腦、電子產品及光學製品製造業 - 47487
# 批發業 - 24412024
# 批發業 - 7240320
# 其他專業、科學及技術服務業 - 108144
# 建築物及綠化服務業 - 53863
# 木竹製品製造業 - 16200
# 金融服務業 - 140314
# 紡織業 - 29568
# 專門營造業 - 1380750
# 人力仲介及供應業 - 960028
# 漁業 - 7780
# 廢水及污水處理業 - 44371
# 人力仲介及供應業 - 564663
# 其他運輸工具及其零件製造業 - 6332
# 用水供應業 - 3782726
# 廢水及污水處理業 - 44703
# 專門設計業 - 167760
# 租賃業 - 2089164
# 未分類其他服務業 - 484042
# 法律及會計服務業 - 334
# 非金屬礦物製品製造業 - 38495
# 機械設備製造業 - 207063
# 電腦程式設計、諮詢及相關服務業 - 2011203
# 不動產開發業 - 2708370
# 保全及偵探業 - 16148
# 飲料製造業 - 132798
# 機械設備製造業 - 92929
# 證券期貨及金融輔助業 - 1327069
# 教育業 - 212600
# 創作及藝術表演業 - 169637
# 電子零組件製造業 - 111807
# 水上運輸業 - 10244
# 餐飲業 - 120860558
# 居住型照顧服務業 - 25400
# 木竹製品製造業 - 13958
# 印刷及資料儲存媒體複製業 - 57656
# 藥品及醫用化學製品製造業 - 143171
# 郵政及快遞業 - 368009
# 影片及電視節目業；聲音錄製及音樂發行業 - 5897163
# 不動產開發業 - 2826378
# 旅行及相關服務業 - 11957
# 公共行政及國防；強制性社會安全 - 259
# 產業用機械設備維修及安裝業 - 5504
# 土木工程業 - 33200
# 專門營造業 - 1859973
# 專門設計業 - 127212
# 保全及偵探業 - 14882
# 污染整治業 - 142
# 其他專業、科學及技術服務業 - 98809
# 宗教、職業及類似組織 - 77759
# 紡織業 - 24501
# 石油及煤製品製造業 - 1029320
# 廢水及污水處理業 - 45538
# 電腦程式設計、諮詢及相關服務業 - 2171709
# 食品及飼品製造業 - 4113903
# 不動產經營及相關服務業 - 1294790
# 人力仲介及供應業 - 1046664
# 紙漿、紙及紙製品製造業 - 19713
# 運動、娛樂及休閒服務業 - 3885151
# 陸上運輸業 - 804697
# 用水供應業 - 4018651
# 運輸輔助業 - 21340799
# 證券期貨及金融輔助業 - 2036205
# 汽車及其零件製造業 - 199281
# 創作及藝術表演業 - 225375
# 石油及天然氣礦業 - 338252
# 教育業 - 280925
# 其他社會工作服務業 - 24166
# 林業 - 2953
# 成衣及服飾品製造業 - 23842
# 非金屬礦物製品製造業 - 35896
# 未分類其他服務業 - 686514
# 砂、石採取及其他礦業 - 2633
# 飲料製造業 - 106261
# 其他化學製品製造業 - 102749
# 機械設備製造業 - 325441
# 圖書館、檔案保存、博物館及類似機構 - 53822
# 石油及天然氣礦業 - 393150
# 水上運輸業 - 9054
# 廣播、電視節目編排及傳播業 - 1517308
# 資訊服務業 - 39070780
# 專門設計業 - 152936
# 皮革、毛皮及其製品製造業 - 10717
# 土木工程業 - 44886
