# %%
import requests
from bs4 import BeautifulSoup as bs
url = "https://www.ptt.cc/bbs/Gossiping/index.html"


prefix = "https://www.ptt.cc"
# cookies = {
#     "over18": "1"
# }
# 發送網頁請求
r = requests.get(url)

soup = bs(r.text, 'lxml')

# containers = soup.select(".r-ent")
# containers = soup.select(".r-ent .title")
# print(containers[0])
title_elements = soup.select(".r-ent .title a")
print(title_elements[0])

for ele in title_elements:
    print(f"標題: {ele.get_text()} 網址: {prefix + ele['href']}")

    ptt_response = requests.get(prefix + ele['href'])

    print(ptt_response.text)
    break
# Out:
# <a href="/bbs/Gossiping/M.1763186667.A.4D9.html">Re: [問卦] 沒想到館長人格有小瑕疵!很扯!!!</a>
# 標題: Re: [問卦] 沒想到館長人格有小瑕疵!很扯!!! 網址: https://www.ptt.cc/bbs/Gossiping/M.1763186667.A.4D9.html
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [問卦] 沒想到館長人格有小瑕疵!很扯!!! - 看板 Gossiping - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="最新爆出的那份錄音檔，整體內容已經不是什麼「個性上有小瑕疵」的程度，而是全面展
# 現出價值觀與人格底線的問題。
# 整理重點如下：
# 1     直接點名怒噴汪小菲與中天蔡董事長
# 錄音中提到：
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [問卦] 沒想到館長人格有小瑕疵!很扯!!!">
# <meta property="og:description" content="最新爆出的那份錄音檔，整體內容已經不是什麼「個性上有小瑕疵」的程度，而是全面展
# 現出價值觀與人格底線的問題。
# 整理重點如下：
# 1     直接點名怒噴汪小菲與中天蔡董事長
# 錄音中提到：
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Gossiping/M.1763186667.A.4D9.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# <script>
# (() => {
#     if (document.cookie.indexOf('over18=1') === -1) {
# 	location = 'https://www.ptt.cc/ask/over18?from=' + encodeURIComponent(location.pathname);
#     }
# })();
# </script>
#
#
# 	</head>
#     <body><a href="https://www.ptt.cc/cdn-cgi/content?id=JTordPc_si8kuxgpV1dfd3tPoI.1_BnqYaTBAdC8yzI-1763187254.4305878-1.0.1.1-Z0BePA4Q5x_tlyMFx6Ur9qUAJQ04cy8URlg9uaAHfoo" aria-hidden="true" rel="nofollow noopener" style="display: none !important; visibility: hidden !important"></a>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Gossiping/index.html">返回看板</a>
# 		<div class="bar"></div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">tn00270144 (乂煞氣a夾小妹乂)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Gossiping</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [問卦] 沒想到館長人格有小瑕疵!很扯!!!</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sat Nov 15 14:04:24 2025</span></div>
# 最新爆出的那份錄音檔，整體內容已經不是什麼「個性上有小瑕疵」的程度，而是全面展
# 現出價值觀與人格底線的問題。
#
#
#
#
# 整理重點如下：
#
# 1     直接點名怒噴汪小菲與中天蔡董事長
#
# 錄音中提到：
#
# 汪小菲：不管跟誰喝酒都能稱兄道弟，但實際沒有任何幫助。
#
# 中天蔡董事長：言語上相當誇張、充滿自我形象塑造，但說得多、做得少。
#
#
#
# 2     承認政治判斷失準，後悔押錯方向
#
# 錄音中表示，當初全力靠攏 柯文哲與黃國昌 是錯誤判斷，如今發現情勢與結果與預期不
# 符，因此萌生「未來得前往中國尋求資金」的想法。
#
#
#
# 3     透露赴中行程是官方觀察性質
#
# 錄音顯示，
# 前往中國的相關活動並非自主開發，而是由官方安排的行程，性質偏向評估、觀察、看他
# 的表現，未來是否能在當地成立公司，取決於後續能否通過考量。
#
#
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 36.229.103.248 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/Gossiping/M.1763186667.A.4D9.html" target="_blank" rel="noreferrer noopener nofollow">https://www.ptt.cc/bbs/Gossiping/M.1763186667.A.4D9.html</a>
# </span></div>
#
#     <div id="article-polling" data-pollurl="/poll/Gossiping/M.1763186667.A.4D9.html?cacheKey=2431-549800877&amp;offset=926&amp;offset-sig=7b0d86e6040199d1bc4e7283a065384ade9aff27" data-longpollurl="/v1/longpoll?id=fe6de41b643367d26bc91faaefb7a7a5c0e7e406" data-offset="926"></div>
#
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'99ec9b742e016af7',t:'MTc2MzE4NzI1NA=='};var a=document.createElement('script');a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
