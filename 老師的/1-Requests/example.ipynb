# %%
import requests
from bs4 import BeautifulSoup as bs
url = "https://www.ptt.cc/bbs/Gossiping/index.html"


prefix = "https://www.ptt.cc"
# cookies = {
#     "over18": "1"
# }
# 發送網頁請求
r = requests.get(url)

soup = bs(r.text, 'lxml')

# containers = soup.select(".r-ent")
# containers = soup.select(".r-ent .title")
# print(containers[0])
title_elements = soup.select(".r-ent .title a")
print(title_elements[0])

for ele in title_elements:
    print(f"標題: {ele.text} 網址: {prefix + ele['href']}")

    ptt_response = requests.get(prefix + ele['href'])

    # print(ptt_response.text)
    break
# Out:
# <a href="/bbs/Gossiping/M.1763197232.A.FE7.html">[問卦] 武力值 棕熊&gt;東北虎&gt;黑熊&gt;=獅子</a>
# 標題: [問卦] 武力值 棕熊>東北虎>黑熊>=獅子 網址: https://www.ptt.cc/bbs/Gossiping/M.1763197232.A.FE7.html
