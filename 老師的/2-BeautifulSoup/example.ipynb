# %%
import requests
from bs4 import BeautifulSoup as bs

url = "https://tw.stock.yahoo.com/quote/2330.TW"
r = requests.get(url)

soup = bs(r.text, 'lxml')

# %%
title_element = soup.find("h1", class_="C($c-link-text) Fw(b) Fz(24px) Mend(8px) Whs(nw)")
title = title_element.text

price_container = soup.find('div', class_="D(f) Ai(fe) Mb(4px)")
# print(price_container)
price = price_container.select_one(".Fz\\(32px\\).Fw\\(b\\)").text 

up_or_down_style = price_container.select_one(".Fz\\(32px\\).Fw\\(b\\)")["class"]
print(up_or_down_style)
print(up_or_down_style[-1])
if up_or_down_style[-1] == 'C($c-trend-down)':
    up_or_down = "跌"
else:
    up_or_down = "漲"


# up_or_down_style = soup.find('span', class_="Mend(4px) Bds(s)")['style']
price = price_container.find(class_=['Fz(32px)', 'Fw(b)']) 
# print(price)
# print(f"Style : {up_or_down_style}")
# Out:
# ['Fz(32px)', 'Fw(b)', 'Lh(1)', 'Mend(16px)', 'D(f)', 'Ai(c)', 'C($c-trend-down)']
# C($c-trend-down)

# %%
a = {
    "A": 10,
    "B": 20
}

print(a.get("C", "未知"))
# Out:
# 未知

# %%
import requests
from bs4 import BeautifulSoup as bs
def get_stock_info(code):
    url = f"https://tw.stock.yahoo.com/quote/{code}.TW"
    r = requests.get(url)

    soup = bs(r.text, 'lxml')
    up_down_mapping = {
        "border-color:transparent transparent #ff333a transparent;border-width:0 6.5px 9px 6.5px": "漲",
        "border-color:#00ab5e transparent transparent transparent;border-width:9px 6.5px 0 6.5px": "跌"
    }

    title_element = soup.find("h1", class_="C($c-link-text) Fw(b) Fz(24px) Mend(8px) Whs(nw)")
    title = title_element.text

    price_container = soup.find('div', class_="D(f) Ai(fe) Mb(4px)")
    # print(price_container)
    price = price_container.select_one(".Fz\\(32px\\)").text
    # price = price_container.find(class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-up)').text # 
    up_or_down_style = soup.find('span', class_="Mend(4px) Bds(s)")['style']
    print(f"Style : {up_or_down_style}")
    # print(up_or_down_style)
    # # print(up_or_down_style)
    up_or_down = up_down_mapping.get(up_or_down_style, "未知")
    percent = price_container.select_one(".Jc\\(fe\\).Fz\\(20px\\)").text

    print(f"{title}: {price} {up_or_down} {percent}")

# %%
stock_codes = ["1303", "2330", "2317", "0050",]
for stock_code in stock_codes:
    get_stock_info(stock_code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 3
#       1 stock_codes = ["1303", "2330", "2317", "0050",]
#       2 for stock_code in stock_codes:
# ----> 3     get_stock_info(stock_code)
#
# Cell In[56], line 14, in get_stock_info(code)
#       8 up_down_mapping = {
#       9     "border-color:transparent transparent #ff333a transparent;border-width:0 6.5px 9px 6.5px": "漲",
#      10     "border-color:#00ab5e transparent transparent transparent;border-width:9px 6.5px 0 6.5px": "跌"
#      11 }
#      13 title_element = soup.find("h1", class_="C($c-link-text) Fw(b) Fz(24px)")
# ---> 14 title = title_element.text
#      16 price_container = soup.find('div', class_="D(f) Ai(fe) Mb(4px)")
#      17 # print(price_container)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup as bs
up_down_mapping = {
    "border-color:transparent transparent #ff333a transparent;border-width:0 6.5px 9px 6.5px": "漲",
    "border-color:#00ab5e transparent transparent transparent;border-width:9px 6.5px 0 6.5px": "跌"
}
url = "https://tw.stock.yahoo.com/quote/1303.TW"
r = requests.get(url)

soup = bs(r.text, 'lxml')
# Mend(4px) Bds(s)
# print(soup)
# D(f) Ai(fe) Mb(4px)
# price = soup.select_one(".D\\(f\\).Ai\\(fe\\).Mb\\(4px\\)")

up_or_down_style = soup.find('span', class_="Mend(4px) Bds(s)")['style']
up_or_down = up_down_mapping[up_or_down_style]
print(up_or_down)

# price.find('span', class_="Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-down)").text
# Out:
# 漲

# %%
import requests
from bs4 import BeautifulSoup as bs


url = "https://finance.yahoo.com/quote/TSLA/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"
}
r = requests.get(url)

soup = bs(r.text, 'lxml')
print(soup)
# Out:
# <html><body><p>Edge: Too Many Requests</p></body></html>

# %%
ele = soup.find(class_="container yf-16vvaki")
print(ele)
# Out:
# <div class="container yf-16vvaki"><div style="display: contents; --_font-weight:var(--font-bold); --_font-size:var(--font-6xl);"><span class="yf-ipw1h0 base" data-testid="qsp-price">404.35 </span></div> <div style="display: contents; --_font-weight:var(--font-bold); --_font-size:var(--font-2xl);"><span class="txt-positive yf-ipw1h0 base" data-testid="qsp-price-change">+2.36 </span></div> <div style="display: contents; --_font-weight:var(--font-bold); --_font-size:var(--font-2xl);"><span class="txt-positive yf-ipw1h0 base" data-testid="qsp-price-change-percent">+(0.59%) </span></div></div>
